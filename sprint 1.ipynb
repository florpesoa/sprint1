# %% [markdown]
# # SPRINT 1

# %% [markdown]
# ##  Exercici 1
# ***A partir dels documents adjunts (estructura i dades), crea una base de dades amb MySQL. Mostra les característiques principals de l'esquema creat i explica les diferents taules i variables que hi ha.***

# %% [markdown]
# Antes de comenzar con el hemos descargado el MySQL para realizar la base de datos.

# %% [markdown]
# Ya descargado el MySQL y los archivos aportadas en el ejercicio, analizamos los .txt para saber de que se tratan y comprender cuales son los tipos de datos con los que trabajaremos.
#
# Observamos que en uno de los .txt tendremos la **estructura general de las tablas**, con sus respectivas columnas y que tipos de datos serán los luego introducidos. Y en el otro, los **datos a introducir**. Ambos están escritos para poder cargarlos directamente en MySQL.

# %% [markdown]
# Tendremos 5 tablas diferentes: tb_movie, tb_movie_person, tb_role, tb_person, tb_genre

# %% [markdown]
# ![diagrama.PNG](attachment:diagrama.PNG)

# %% [markdown]
#   Cada una de ellas, se encuentra relacionada con otra por medio de una *foreing key*, que es la relación entre un valor de una tabla actual y el de otra. En el caso de la imagen podemos observar que las variables de tb_movie_person se relaciona con tb_role, tb_person y tb_movie. Sin embargo, tb_genre solo se relaciona con tb_movie por medio de genre_id.
#   Otra cosa a observar, es la relación interna que hay en tb_person entre person_id y person_parent_id, que relaciona los padres de los actores que a su vez también son famosos.
#   También en cada una de las tablas podemos ver que tipo de variable tenemos, ya sea un integer, date y cuales son de carácter variable (VARCHAR).

# %% [markdown]
# # Exercici 2

# %% [markdown]
# ***Realitza la següent consulta sobre la base de dades acabada de crear:***
#
# ***Has d'obtenir el nom, el país i la data de naixement d'aquelles persones per les quals no consti una data de mort i ordenar les dades de la persona més vella a la persona més jove.***

# %% [markdown]
# Para realizar la consulta primero seleccionamos las columnas que son necesarias para esto, lo haremos  por medio de SELECT (nombre, fecha de nacimiento y país) y por medio del FROM nos referimos a la tabla de la cual queremos que se extraigan.
# También necesitaremos especificar que tipo de datos queremos por medio de WHERE: person_dod (fecha de muerte) es nula, o sea que siguen vivos, y por medio del ORDER BY que lo ordene por fecha ascendente.

# %% [markdown]
# ![ej2.1.PNG](attachment:ej2.1.PNG)

# %% [markdown]
# El resultado será:

# %% [markdown]
# ![ej2.2.PNG](attachment:ej2.2.PNG)

# %% [markdown]
# # Exercici 3

# %% [markdown]
# **Realitza la següent consulta sobre la base de dades acabada de crear:**
#
# **Has d'obtenir el nom del gènere i el nombre total de pel·lícules d'aquest gènere i ordenar-ho per ordre descendent de nombre total de pel·lícules.**

# %% [markdown]
# - Seleccionaremos las columnas genre_id, genre_name de la tabla tb_genre y por medio del COUNT, el cual sirve para contar la cantidad de registros de una tabla usaremos el asterisco para hacerlo con todos, y con el AS le damos un nuevo nombre a este resultado que será: count_movies.
# <br>
#
# - Apartir del inner join seleccionamos de la tabla tb_genre las 2 columnas que queremos utilizar, en este caso "genre_id" y "genre_name". Así, podremos saber que género es el nombrado por el id correspondiente.
# <br>
# - Nos falta contar cuantos de cada género hay par apoder cumplir con nuestra tarea agrupamos por medio de GROUP BY por genre_name y ordenamos por conteo de cada genero (nombrado por medio del AS "count_movies")
# <br>
# - Agregamos DESC para poder ordenarlo de orden descendente de cantidad de peliculas de cada género

# %% [markdown]
# ![ej3.1.PNG](attachment:ej3.1.PNG)

# %% [markdown]
# El resultado será:

# %% [markdown]
# ![ej3.2.PNG](attachment:ej3.2.PNG)

# %% [markdown]
# Podemos observar que el género con más peliculas en nuestra base de datos es el de Comedia.

# %% [markdown]
# # Exercici 4

# %% [markdown]
# **Realitza la següent consulta sobre la base de dades acabada de crear:**
#
# **Has d'obtenir, per a cada persona, el seu nom i el nombre màxim de rols diferents que ha tingut en una mateixa pel·lícula.**
#
# **Posteriorment, mostra únicament aquelles persones que hagin assumit més d'un rol en una mateixa pel·lícula.**

# %% [markdown]
# Seleccionamos la columna person_name de la tabla tb_person, con SELECT y FROM.
# De las cuales, por medio del COUNT y especificando que columna y de que tabla realice el conteo de roles que tiene, en este caso como queremos saber la cantidad de roles por película será: tb_movie_person.role_id, utilizaremos el AS para nombrar a esta nueva columna como howmany_roles y así utilizarla más fácilmente si queremos realizar otra consulta.
# <br>
# <br>
# Utilizaremos el INNER JOIN con la tabla tb_movie_person para que nos devuelva todas las filas donde hay al menos una coincidencia en ambas tablas, y el ON especifica cuales de las 2 columnas son las que relacionan la tabla, en este caso tb_movie_person.person_id con tb_person.person_id.
# <br>
# <br>
# Luego, por medio del GROUP BY, agruparemos por movie_id y person_id para poder diferenciar el actor y la pelicula en la que actuó.
# <br>
# <br>
# El HAVING sirve para que a partir de la clausula group by que se utilizó antes, se seleccione los datos que satisfagan la clausula que le pongamos a la mmisma. En este caso, le especificaremos que seleccione únciamente los howmany_roles mayores a 1, así solo tendremos en la tabla resutlando aquellos actores que tuvieron más de un rol en la película.
# <br>
# <br>
# Por último, el ORDER BY los ordenará a partir de los valores de howmany_roles y en orden ascendente decretado por el ASC.

# %% [markdown]
# ![ej4.PNG](attachment:ej4.PNG)

# %% [markdown]
# El resultado será:

# %% [markdown]
# ![ej4.b.PNG](attachment:ej4.b.PNG)

# %% [markdown]
# Podemos observar como Coppola y Hitchcock son los que más roles han tenido en una misma película.

# %% [markdown]
# # Exercici 5

# %% [markdown]
# **Realitza la següent operació sobre la base de dades acabada de crear:**
#
# **Has de crear un nou gènere anomenat "Documental" el qual tingui com a identificador el nombre 69.**

# %% [markdown]
# My SQL presenta la opción de editar tabla directamente en el visualizador de código, en el caso que querramos agregar una fila lo podemos hacer directamente y este lo incorpora a la misma con su código y demás.
# <br>
# Por lo que agregamos el nuevo género: Documental y su id correspondiente ue pedia el ejercicio: 69

# %% [markdown]
# ![ej5.PNG](attachment:ej5.PNG)

# %% [markdown]
# # Exercici 6

# %% [markdown]
# **Fes la següent operació sobre la base de dades acabada de crear:**
#
# **Elimina la pel·lícula "La Gran Familia Española" de la base de dades.**

# %% [markdown]
# Siguiendo con la metodología del ejercicio anterior, podemos eliminar directamente del visulizador las filas que querramos y se quitarán directamente de nuestra base de datos. Debemos saber que estos son cambios permanentes.

# %% [markdown]
# ![ej6.PNG](attachment:ej6.PNG)

# %% [markdown]
# ![ej6.2.PNG](attachment:ej6.2.PNG)

# %% [markdown]
# # Exercici 7

# %% [markdown]
# **Realitza la següent operació sobre la base de dades acabada de crear:**
#
# **Canvia el gènere de la pel·lícula "Ocho apellidos catalanes" perquè consti com a comèdia i no com a romàntica.**

# %% [markdown]
# Se cambio directamente sobre la base de datos el género de la película indicada![ej7.PNG](attachment:ej7.PNG)

# %% [markdown]
# El género correspondiente a comedia es el 3 y es por el que se ha cambiado.
